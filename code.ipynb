# %% [markdown]
# <a href="https://colab.research.google.com/github/dkasturi-web/se-lab/blob/main/code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

def quadratic_temperature_model(day, a, b, c):
    # Quadratic equation for temperature
    temperature = a * day**2 + b * day + c
    return temperature

def main():
    # Fixed coefficients for the quadratic equation: ax^2 + bx + c
    a, b, c = 1, -3, 2

    # Fixed number of days to model
    num_days = int(input("Enter the number of days to model: "))

    # Lists to store day and corresponding temperature values
    days = list(range(1, num_days + 1))
    temperatures = [quadratic_temperature_model(day, a, b, c) for day in days]

    # Plotting
    plt.plot(days, temperatures, label=f'Temperature: {a}x² + {b}x + {c}')
    plt.title('Weather Modeling')
    plt.xlabel('Day')
    plt.ylabel('Temperature (°C)')
    plt.legend()
    plt.grid(True)
    plt.show()

main()
# Out:
# Enter the number of days to model: 20

# %%
import matplotlib.pyplot as plt

def quadratic_temperature_model(day, a, b, c):
    temperature = a * day**2 + b * day + c
    return temperature

def main():
    # Hard-coded coefficients for the quadratic equation: ax^2 + bx + c
    a = float(input("Enter the quadratic coefficient (a): "))
    b = float(input("Enter the linear coefficient (b): "))
    c = float(input("Enter the constant term (c): "))

    # Get user input for the number of days to model
    num_days = int(input("Enter the number of days to model: "))

    # Create list of days
    days = list(range(1, num_days + 1))

    # Calculate temperature for each day
    temperatures = [quadratic_temperature_model(day, a, b, c) for day in days]

    # Plotting
    plt.plot(days, temperatures, marker='o', label=f'Temperature: {a}x² + {b}x + {c}')
    plt.title('Weather Modeling')
    plt.xlabel('Day')
    plt.ylabel('Temperature (°C)')
    plt.grid()
    plt.legend()
    plt.show()

main()
# Out:
# Enter the quadratic coefficient (a): 20
# Enter the linear coefficient (b): 10
# Enter the constant term (c): 30
# Enter the number of days to model: 25
